# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import dotenv
import os

# %%
Application_df = pd.read_csv("data/Application.csv", encoding='utf-8')

# %%
Application_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 340730 entries, 0 to 340729
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        340730 non-null  int64
#  1   cdate             340730 non-null  str
#  2   company_uuid      340730 non-null  str
#  3   job_uuid          340730 non-null  str
#  4   user_uuid         340730 non-null  str
#  5   application_uuid  340730 non-null  str
# dtypes: int64(1), str(5)
# memory usage: 15.6 MB

# %%
Application_df
# Out:
#         Unnamed: 0                       cdate  \
# 0                0         2017-02-25 23:45:01
# 1                1  2020-11-23 14:46:07.329731
# 2                2  2017-10-28 22:30:10.631568
# 3                3  2017-07-03 17:40:05.317255
# 4                4         2017-02-10 10:53:39
# ...            ...                         ...
# 340725      340725  2021-05-09 16:48:46.908545
# 340726      340726  2022-03-20 22:21:29.175182
# 340727      340727  2022-04-07 09:41:05.036134
# 340728      340728  2022-07-15 04:22:09.138346
# 340729      340729  2023-07-10 10:02:03.071155
#
#                                 company_uuid  \
# 0       de4b3596-b4ab-47cd-b8ea-6f9e14170064
# 1       f6156b12-d4d7-469f-84be-31799c765211
# 2       2ed05b18-c735-474a-9faa-02095b25729a
# 3       3d6730ee-b869-47b7-90c6-1e074e4eb15b
# 4       de4b3596-b4ab-47cd-b8ea-6f9e14170064
# ...                                      ...
# 340725  214c0ee9-4fc9-46be-ba8a-2a0368510e80
# ...

# %%
Application_df.drop(['Unnamed: 0'], axis=1,inplace=True)

# %%
Application_df['cdate'] = pd.to_datetime(Application_df['cdate'], format='mixed')

# %%
Application_df.describe(include=all)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 Application_df.describe(include=all)
#
# File d:\vscode\dataanalyst\.venv\Lib\site-packages\pandas\core\generic.py:11426, in NDFrame.describe(self, percentiles, include, exclude)
#   11180 @final
#   11181 def describe(
#   11182     self,
#    (...)  11185     exclude=None,
#   11186 ) -> Self:
#   11187     """
#   11188     Generate descriptive statistics.
#   11189
#    (...)  11424     max            NaN      3.0
#   11425     """
# > 11426     return describe_ndframe(
#   11427         obj=self,
#   11428         include=include,
#   11429         exclude=exclude,
#   11430         percentiles=percentiles,
#   11431     ).__finalize__(self, method="describe")
#
# ...

# %%
Application_df[Application_df['cdate'].duplicated()]
# 시간이 초 단위까지 똑같은건 불가능하니까 제거하는게 맞다
Application_df = Application_df.drop_duplicates(subset=['cdate'],keep='first')

# %%
print('heelo')
